# %%
import pandas as pd
import numpy as np

# %%
#Import dataframe
raw_data = pd.read_csv(r'C:\Users\Khew Min Shiu\NS1-AAPL_US.csv')
raw_data
# Out:
#           Date  Sentiment  Sentiment High  Sentiment Low  News Volume  \
# 0   2017-12-20        1.0             4.0           -2.0         29.0
# 1   2017-12-19        1.0             3.0           -3.0         86.0
# 2   2017-12-18        1.0             4.0           -2.0         42.0
# 3   2017-12-17        2.0             4.0           -2.0         20.0
# 4   2017-12-16        2.0             5.0           -1.0         29.0
# 5   2017-12-15        3.0             5.0            2.0         47.0
# 6   2017-12-14        3.0             5.0            1.0         70.0
# 7   2017-12-13        2.0             4.0           -1.0         87.0
# 8   2017-12-12        1.0             4.0           -2.0         92.0
# 9   2017-12-11        2.0             4.0           -2.0         65.0
# 10  2017-12-10        3.0             5.0            1.0         19.0
# 11  2017-12-09        2.0             4.0           -2.0         21.0
# 12  2017-12-08        2.0             5.0           -2.0         49.0
# 13  2017-12-07        2.0             5.0           -1.0         77.0
# 14  2017-12-06        2.0             4.0           -1.0         79.0
# 15  2017-12-05        2.0             4.0           -2.0         53.0
# 16  2017-12-04       -1.0             2.0           -3.0         17.0
# 17  2017-12-03        2.0             4.0           -2.0         24.0
# 18  2017-12-02        1.0             3.0           -2.0          2.0
# 19  2017-12-01       -2.0             2.0           -4.0         18.0
# 20  2017-11-30        2.0             4.0           -2.0         36.0
# 21  2017-11-29        2.0             4.0           -2.0         42.0
# 22  2017-11-28        2.0             3.0           -1.0         15.0
# 23  2017-11-27        2.0             3.0           -1.0         14.0
# 24  2017-11-26        0.0             0.0            0.0          0.0
# 25  2017-11-25       -1.0             2.0           -3.0         13.0
# 26  2017-11-24        1.0             3.0           -2.0         15.0
# 27  2017-11-23        1.0             3.0           -2.0         16.0
# 28  2017-11-22        1.0             4.0           -2.0         59.0
# 29  2017-11-21        2.0             4.0           -2.0        103.0
# ..         ...        ...             ...            ...          ...
# 62  2017-10-19       -1.0             2.0           -3.0         48.0
# 63  2017-10-18        2.0             4.0           -2.0         35.0
# 64  2017-10-17        1.0             2.0           -2.0         39.0
# 65  2017-10-16        1.0             2.0           -2.0         22.0
# 66  2017-10-15       -1.0             2.0           -3.0         21.0
# 67  2017-10-14        1.0             4.0           -2.0         11.0
# 68  2017-10-13        2.0             4.0           -2.0         51.0
# 69  2017-10-12       -1.0             2.0           -2.0         13.0
# 70  2017-10-11        1.0             3.0           -2.0         38.0
# 71  2017-10-10        1.0             3.0           -3.0         17.0
# 72  2017-10-09        0.0             0.0            0.0          0.0
# 73  2017-10-08        0.0             0.0            0.0          0.0
# 74  2017-10-07        0.0             0.0            0.0          0.0
# 75  2017-10-06        0.0             0.0            0.0          0.0
# 76  2017-10-05        0.0             0.0            0.0          0.0
# 77  2017-10-04        0.0             0.0            0.0          0.0
# 78  2017-10-03        0.0             0.0            0.0          0.0
# 79  2017-10-02        0.0             0.0            0.0          0.0
# 80  2017-10-01        0.0             0.0            0.0          0.0
# 81  2017-09-30        0.0             0.0            0.0          0.0
# 82  2017-09-29        0.0             0.0            0.0          0.0
# 83  2017-09-28        0.0             0.0            0.0          0.0
# 84  2017-09-27        0.0             0.0            0.0          0.0
# 85  2017-09-26       -1.0             2.0           -3.0         73.0
# 86  2017-09-25       -1.0             2.0           -3.0         35.0
# 87  2017-09-24       -1.0             2.0           -3.0         10.0
# 88  2017-09-23       -1.0             1.0           -3.0         27.0
# 89  2017-09-22       -1.0             2.0           -2.0         36.0
# 90  2017-09-21       -2.0            -1.0           -3.0          3.0
# 91  2017-09-20        3.0             5.0            1.0          5.0
#
#     News Buzz
# 0         4.0
# 1        10.0
# 2         8.0
# 3         7.0
# 4         6.0
# 5         6.0
# 6         9.0
# 7        10.0
# 8        10.0
# 9        10.0
# 10        6.0
# 11        6.0
# 12        7.0
# 13       10.0
# 14       10.0
# 15       10.0
# 16        8.0
# 17        7.0
# 18        2.0
# 19        4.0
# 20        8.0
# 21       10.0
# 22        2.0
# 23        3.0
# 24        0.0
# 25        2.0
# 26        2.0
# 27        2.0
# 28        7.0
# 29       10.0
# ..        ...
# 62       10.0
# 63        7.0
# 64        8.0
# 65       10.0
# 66        9.0
# 67        7.0
# 68       10.0
# 69        3.0
# 70       10.0
# 71        9.0
# 72        0.0
# 73        0.0
# 74        0.0
# 75        0.0
# 76        0.0
# 77        0.0
# 78        0.0
# 79        0.0
# 80        0.0
# 81        0.0
# 82        0.0
# 83        0.0
# 84        0.0
# 85        7.0
# 86        7.0
# 87        5.0
# 88        4.0
# 89        3.0
# 90        3.0
# 91        1.0
#
# [92 rows x 6 columns]

# %%
raw_data['Sentiment'].describe()
# Out:
# count    92.000000
# mean      0.652174
# std       1.287597
# min      -2.000000
# 25%       0.000000
# 50%       1.000000
# 75%       2.000000
# max       3.000000
# Name: Sentiment, dtype: float64

# %%
raw_data['News Buzz'].describe()
# Out:
# count    92.000000
# mean      5.782609
# std       3.851148
# min       0.000000
# 25%       2.000000
# 50%       6.500000
# 75%      10.000000
# max      10.000000
# Name: News Buzz, dtype: float64

# %%
#A brief statistic on difference of sentiment on a day
sentiment_diff = raw_data['Sentiment High'] - raw_data['Sentiment Low']
sentiment_diff.describe()
# Out:
# count    92.000000
# mean      4.250000
# std       2.265969
# min       0.000000
# 25%       4.000000
# 50%       5.000000
# 75%       6.000000
# max       7.000000
# dtype: float64

# %%
positive = np.sum((raw_data['Sentiment'] > 0) * 1)
high = np.sum( (raw_data['Sentiment High']>0)*1 * (raw_data['Sentiment Low']>0)*1)
low = np.sum( (raw_data['Sentiment High']<0)*1 * (raw_data['Sentiment Low']<0)*1)

print('There is a total of %d positive sentiment values on news/articles/social media across the 3 months period.'%positive)
print('Besides that, %d day(s) are totally positive and %d day(s) are totally negative in sentiment values.'%(high,low))
# Out:
# There is a total of 53 positive sentiment values on news/articles/social media across the 3 months period.
# Besides that, 4 day(s) are totally positive and 1 day(s) are totally negative in sentiment values.

# %%
print('The sum of news volume for Apple in US from 2017-09-20 to 2017-12-20 is %d.'%raw_data['News Volume'].sum())
# Out:
# The sum of news volume for Apple in US from 2017-09-20 to 2017-12-20 is 2801.

# %%
temp_df = raw_data[raw_data['Sentiment'] == 0]
print('In a total of 3 months period, there is %d day(s) which this asset has zero sentiment and buzz.'%temp_df['Date'].count())
# Out:
# In a total of 3 months period, there is 18 day(s) which this asset has zero sentiment and buzz.

# %%
#Build a ordinary least square model to predict sentiment
from statsmodels.formula.api import ols
Y_positive = raw_data[raw_data['Sentiment'] >= 0 ]['Sentiment']
Y_negative = raw_data[raw_data['Sentiment'] < 0 ]['Sentiment']
X_positive = raw_data[raw_data['Sentiment'] >= 0 ]['News Volume']
X_negative = raw_data[raw_data['Sentiment'] < 0 ]['News Volume']
df_positive = pd.DataFrame(data={'Y':Y_positive, 'X':X_positive}) 
model_1 = ols("Y ~ X",df_positive).fit()
print(model_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.263
# Model:                            OLS   Adj. R-squared:                  0.252
# Method:                 Least Squares   F-statistic:                     24.61
# Date:                Thu, 21 Dec 2017   Prob (F-statistic):           4.83e-06
# Time:                        21:17:41   Log-Likelihood:                -81.004
# No. Observations:                  71   AIC:                             166.0
# Df Residuals:                      69   BIC:                             170.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7096      0.134      5.294      0.000       0.442       0.977
# X              0.0164      0.003      4.961      0.000       0.010       0.023
# ==============================================================================
# Omnibus:                        6.058   Durbin-Watson:                   1.199
# Prob(Omnibus):                  0.048   Jarque-Bera (JB):                6.089
# Skew:                           0.713   Prob(JB):                       0.0476
# Kurtosis:                       2.848   Cond. No.                         59.8
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df_negative = pd.DataFrame(data={'Y':Y_negative, 'X':X_negative}) 
model_2 = ols("Y ~ X", df_negative).fit()
print(model_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1.204
# Date:                Thu, 21 Dec 2017   Prob (F-statistic):              0.286
# Time:                        21:17:41   Log-Likelihood:                -9.5223
# No. Observations:                  21   AIC:                             23.04
# Df Residuals:                      19   BIC:                             25.13
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.3353      0.158     -8.438      0.000      -1.667      -1.004
# X              0.0044      0.004      1.097      0.286      -0.004       0.013
# ==============================================================================
# Omnibus:                        8.431   Durbin-Watson:                   1.596
# Prob(Omnibus):                  0.015   Jarque-Bera (JB):                6.951
# Skew:                          -1.404   Prob(JB):                       0.0309
# Kurtosis:                       3.251   Cond. No.                         70.9
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from sklearn.svm import SVC
svc = SVC(kernel = 'linear')
svc.fit(X_positive.reshape(-1,1),Y_positive.reshape(-1,1))
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   app.launch_new_instance()
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred_positive = [svc.predict(70),svc.predict(50),svc.predict(0)]
y_pred_positive
# Out:
# [array([ 2.]), array([ 1.]), array([ 0.])]

# %%
from sklearn.svm import SVC
svc_2 = SVC(kernel = 'linear')
svc_2.fit(X_negative.reshape(-1,1),Y_negative.reshape(-1,1))
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   app.launch_new_instance()
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred_negative = [svc_2.predict(70),svc_2.predict(50),svc_2.predict(10)]
y_pred_negative
# Out:
# [array([-1.]), array([-1.]), array([-1.])]
