# 79  2017-10-02        0.0             0.0            0.0          0.0
# 80  2017-10-01        0.0             0.0            0.0          0.0
# 81  2017-09-30        0.0             0.0            0.0          0.0
# 82  2017-09-29        0.0             0.0            0.0          0.0
# 83  2017-09-28        0.0             0.0            0.0          0.0
# 84  2017-09-27       -1.0            -1.0           -1.0          1.0
# 85  2017-09-26       -1.0             2.0           -2.0        186.0
# 86  2017-09-25       -1.0             2.0           -3.0        131.0
# 87  2017-09-24       -1.0             3.0           -3.0         67.0
# 88  2017-09-23       -1.0             2.0           -4.0         65.0
# 89  2017-09-22       -1.0             3.0           -3.0        134.0
# 90  2017-09-21        0.0             0.0            0.0          0.0
# 91  2017-09-20        0.0             0.0            0.0          0.0
#
#     News Buzz
# 0         7.0
# 1        10.0
# 2        10.0
# 3        10.0
# 4        10.0
# 5         9.0
# 6        10.0
# 7        10.0
# 8        10.0
# 9        10.0
# 10       10.0
# 11       10.0
# 12       10.0
# 13       10.0
# 14       10.0
# 15       10.0
# 16       10.0
# 17        8.0
# 18        2.0
# 19        5.0
# 20       10.0
# 21       10.0
# 22        0.0
# 23        0.0
# 24        0.0
# 25        3.0
# 26        3.0
# 27        0.0
# 28        8.0
# 29       10.0
# ..        ...
# 62       10.0
# 63       10.0
# 64       10.0
# 65       10.0
# 66       10.0
# 67       10.0
# 68       10.0
# 69       10.0
# 70        9.0
# 71       10.0
# 72        0.0
# 73       10.0
# 74       10.0
# 75       10.0
# 76       10.0
# 77        0.0
# 78        0.0
# 79        0.0
# 80        0.0
# 81        0.0
# 82        0.0
# 83        0.0
# 84        0.0
# 85       10.0
# 86       10.0
# 87       10.0
# 88        8.0
# 89        8.0
# 90        0.0
# 91        0.0
#
# [92 rows x 6 columns]

# %%
raw_data['Sentiment'].describe()
# Out:
# count    92.000000
# mean      0.206522
# std       0.978202
# min      -2.000000
# 25%      -1.000000
# 50%       0.500000
# 75%       1.000000
# max       2.000000
# Name: Sentiment, dtype: float64

# %%
raw_data['News Buzz'].describe()
# Out:
# count    92.000000
# mean      7.032609
# std       4.096235
# min       0.000000
# 25%       3.000000
# 50%      10.000000
# 75%      10.000000
# max      10.000000
# Name: News Buzz, dtype: float64

# %%
#A brief statistic on difference of sentiment on a day
sentiment_diff = raw_data['Sentiment High'] - raw_data['Sentiment Low']
sentiment_diff.describe()
# Out:
# count    92.000000
# mean      4.032609
# std       2.250524
# min       0.000000
# 25%       4.000000
# 50%       5.000000
# 75%       5.000000
# max       8.000000
# dtype: float64

# %%
positive = np.sum((raw_data['Sentiment'] > 0) * 1)
high = np.sum( (raw_data['Sentiment High']>0)*1 * (raw_data['Sentiment Low']>0)*1)
low = np.sum( (raw_data['Sentiment High']<0)*1 * (raw_data['Sentiment Low']<0)*1)

print('There is a total of %d positive sentiment values on news/articles/social media across the 3 months period.'%positive)
print('Besides that, %d day(s) are totally positive and %d day(s) are totally negative in sentiment values.'%(high,low))
# Out:
# There is a total of 46 positive sentiment values on news/articles/social media across the 3 months period.
# Besides that, 3 day(s) are totally positive and 2 day(s) are totally negative in sentiment values.

# %%
print('The sum of news volume for Apple in US from 2017-09-20 to 2017-12-20 is %d.'%raw_data['News Volume'].sum())
# Out:
# The sum of news volume for Apple in US from 2017-09-20 to 2017-12-20 is 11534.

# %%
temp_df = raw_data[raw_data['Sentiment'] == 0]
print('In a total of 3 months period, there is %d day(s) which this asset has zero sentiment and buzz.'%temp_df['Date'].count())
# Out:
# In a total of 3 months period, there is 16 day(s) which this asset has zero sentiment and buzz.

# %%
#Build a ordinary least square model to predict sentiment
from statsmodels.formula.api import ols
Y_positive = raw_data[raw_data['Sentiment'] >= 0 ]['Sentiment']
Y_negative = raw_data[raw_data['Sentiment'] < 0 ]['Sentiment']
X_positive = raw_data[raw_data['Sentiment'] >= 0 ]['News Volume']
X_negative = raw_data[raw_data['Sentiment'] < 0 ]['News Volume']
df_positive = pd.DataFrame(data={'Y':Y_positive, 'X':X_positive}) 
model_1 = ols("Y ~ X",df_positive).fit()
print(model_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.166
# Model:                            OLS   Adj. R-squared:                  0.152
# Method:                 Least Squares   F-statistic:                     11.95
# Date:                Thu, 21 Dec 2017   Prob (F-statistic):            0.00101
# Time:                        21:17:36   Log-Likelihood:                -43.443
# No. Observations:                  62   AIC:                             90.89
# Df Residuals:                      60   BIC:                             95.14
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.5629      0.094      5.958      0.000       0.374       0.752
# X              0.0020      0.001      3.457      0.001       0.001       0.003
# ==============================================================================
# Omnibus:                       21.220   Durbin-Watson:                   1.401
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               30.900
# Skew:                           1.283   Prob(JB):                     1.95e-07
# Kurtosis:                       5.318   Cond. No.                         251.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df_negative = pd.DataFrame(data={'Y':Y_negative, 'X':X_negative}) 
model_2 = ols("Y ~ X", df_negative).fit()
print(model_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.113
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     3.578
# Date:                Thu, 21 Dec 2017   Prob (F-statistic):             0.0689
# Time:                        21:17:36   Log-Likelihood:                 10.762
# No. Observations:                  30   AIC:                            -17.52
# Df Residuals:                      28   BIC:                            -14.72
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.1437      0.067    -17.190      0.000      -1.280      -1.007
# X              0.0009      0.000      1.892      0.069   -7.23e-05       0.002
# ==============================================================================
# Omnibus:                       61.967   Durbin-Watson:                   2.167
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              547.175
# Skew:                          -4.276   Prob(JB):                    1.52e-119
# Kurtosis:                      22.094   Cond. No.                         301.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from sklearn.svm import SVC
svc_1 = SVC(kernel = 'linear')
svc_1.fit(X_positive.reshape(-1,1),Y_positive.reshape(-1,1))
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   app.launch_new_instance()
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred = [svc_1.predict(100),svc_1.predict(50),svc_1.predict(0)]
y_pred
# Out:
# [array([ 1.]), array([ 1.]), array([ 0.])]

# %%
from sklearn.svm import SVC
svc_2 = SVC(kernel = 'linear')
svc_2.fit(X_negative.reshape(-1,1),Y_negative.reshape(-1,1))
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   app.launch_new_instance()
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:526: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred = [svc_2.predict(100),svc_2.predict(50),svc_2.predict(10)]
y_pred
# Out:
# [array([-1.]), array([-1.]), array([-1.])]
